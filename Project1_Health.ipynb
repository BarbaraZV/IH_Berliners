# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from IPython.display import Image
from IPython.display import HTML
from IPython.display import Markdown, display
def printmd(string):display(Markdown(string))
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100
import matplotlib.pyplot as plt
from scipy.stats import norm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import quantile_transform
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder  ##. better to use dummy from pandas 
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %% [markdown]
# ## Reading the dataframe

# %%
def load_original_data():
    filename = "Data/demographic country data.xlsx"
    file1 = pd.read_excel (filename, index_col=False)
    #hk_df = pd.read_csv(filename, index_col=False)
    return file1

# %%
df1 = load_original_data()
df1
# Out:
#              Row Labels  \
# 0           Afghanistan
# 1               Albania
# 2               Algeria
# 3        American Samoa
# 4               Andorra
# ..                  ...
# 253  West Bank and Gaza
# 254               World
# 255         Yemen, Rep.
# 256              Zambia
# 257            Zimbabwe
#
#      % of females ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
#
#      % of males ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
#
#      Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
#
#      Adults (ages 15+) and children (0-14 years) living with HIV  \
# 0                                               6900.0
# 1                                                  NaN
# 2                                               8800.0
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                         36700000.0
# 255                                             9200.0
# 256                                          1200000.0
# 257                                          1400000.0
#
#      Adults (ages 15+) and children (ages 0-14) newly infected with HIV  \
# 0                                               1000.0
# 1                                                  NaN
# 2                                                500.0
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                          2100000.0
# 255                                             1000.0
# 256                                            60000.0
# 257                                            64000.0
#
#      Adults (ages 15+) living with HIV  \
# 0                               6700.0
# 1                                  NaN
# 2                               8600.0
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 253                                NaN
# 254                         34900000.0
# 255                             8800.0
# 256                          1100000.0
# 257                          1300000.0
#
#      Adults (ages 15+) newly infected with HIV  Age at first marriage, female  \
# 0                                       1000.0                            NaN
# 1                                          NaN                            NaN
# 2                                        500.0                            NaN
# 3                                          NaN                            NaN
# 4                                          NaN                            NaN
# ..                                         ...                            ...
# 253                                        NaN                            NaN
# 254                                  1900000.0                            NaN
# 255                                     1000.0                            NaN
# 256                                    55000.0                            NaN
# 257                                    59000.0                            NaN
#
#      Age at first marriage, male  ...  Urban population (% of total)  \
# 0                            NaN  ...                      26.703000
# 1                            NaN  ...                      57.407000
# 2                            NaN  ...                      70.727000
# 3                            NaN  ...                      87.202000
# 4                            NaN  ...                      85.115000
# ..                           ...  ...                            ...
# 253                          NaN  ...                      75.252000
# 254                          NaN  ...                      53.857238
# 255                          NaN  ...                      34.606000
# 256                          NaN  ...                      40.922000
# 257                          NaN  ...                      32.376000
#
#      Urban population growth (annual %)  \
# 0                              4.392152
# 1                              1.598580
# 2                              2.712200
# 3                              0.115698
# 4                             -3.836562
# ..                                  ...
# 253                            3.225469
# 254                            2.054434
# 255                            4.133982
# 256                            4.177551
# 257                            1.928627
#
#      Urban poverty headcount ratio at national poverty lines (% of urban population)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
#
#      Use of any antimalarial drug (% of pregnant women)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
#
#      Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
#
#      Use of Intermittent Preventive Treatment of malaria, 2+ doses of SP/Fansidar (% of pregnant women)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
#
#      Vitamin A supplementation coverage rate (% of children ages 6-59 months)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
#
#      Wanted fertility rate (births per woman)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 253                                       NaN
# 254                                       NaN
# 255                                       NaN
# 256                                       NaN
# 257                                       NaN
#
#      Women's share of population ages 15+ living with HIV (%)   Grand Total
# 0                                            28.575694         2.257291e+08
# 1                                                  NaN         1.846349e+07
# 2                                            45.725948         2.567538e+08
# 3                                                  NaN         1.116666e+05
# 4                                                  NaN         1.421499e+05
# ..                                                 ...                  ...
# 253                                                NaN         2.952038e+07
# 254                                          50.836254         4.485283e+10
# 255                                          41.098550         1.850650e+08
# 256                                          57.244490         1.186270e+08
# 257                                          58.855551         1.121429e+08
#
# [258 rows x 347 columns]
