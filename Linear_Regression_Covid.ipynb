# %% [markdown]
# ## Covid Case Study using Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
## Install xlrd package to load Excel files
# conda install openpyxl
## conda install xlrd

# %%
folder_path = r"Data\\5. Updated with continent codes\nutrition_demographic_covid_continent_2.csv"

df= pd.read_csv(folder_path)

# %%
df
# Out:
#      covid_fatality_rate      continent              country  \
# 0               0.000226           asia          afghanistan
# 1               0.001113         europe              albania
# 2               0.000158         africa              algeria
# 3               0.000071         africa               angola
# 4               0.001296  north america  antigua and barbuda
# ..                   ...            ...                  ...
# 157             0.000074           asia                yemen
# 158             0.000230         africa               zambia
# 159             0.000321         africa             zimbabwe
# 160             0.001147        oceania        new caledonia
# 161             0.002295        oceania     french polynesia
#
#      covid_confirmed_cases  \
# 0                   158084
# 1                   210224
# 2                   218432
# 3                    81593
# 4                     4283
# ..                     ...
# 157                  10126
# 158                 254274
# 159                 213258
# 160                  63515
# 161                 732268
#
#      age dependency ratio (% of working-age population)  \
# 0                                            86.954464
# 1                                            44.806973
# 2                                            52.617579
# 3                                            99.855751
# 4                                            45.650381
# ..                                                 ...
# 157                                          75.595147
# 158                                          95.402326
# 159                                          80.391033
# 160                                          47.920177
# 161                                          42.229689
#
#      age dependency ratio, old  age population, age 0, female, interpolated  \
# 0                     4.616073                                     470554.0
# 1                    17.950766                                      21438.0
# 2                     9.062490                                     459353.0
# 3                     4.623604                                     502641.0
# 4                    10.434645                                        734.0
# ..                         ...                                          ...
# 157                   4.893864                                     392662.0
# 158                   5.683539                                     295178.0
# 159                   5.347744                                     262428.0
# 160                  15.042344                                       1990.0
# 161                  10.738501                                       2952.0
#
#      diabetes prevalence (% of population ages 20 to 79)  \
# 0                                                  8.8
# 1                                                 10.3
# 2                                                  7.5
# 3                                                  4.1
# 4                                                 13.6
# ..                                                 ...
# 157                                                5.1
# 158                                                4.1
# 159                                                3.9
# 160                                               19.6
# 161                                               19.4
#
#      female population 45-49  female population 80+  ...  kcal_vegetable oils  \
# 0                   496113.0                43481.0  ...               2.3012
# 1                    97198.0                41381.0  ...               2.8244
# 2                  1053861.0               253907.0  ...               5.7638
# 3                   383280.0                38663.0  ...               4.2741
# 4                     4400.0                  947.0  ...               4.6904
# ..                       ...                    ...  ...                  ...
# 157                 409910.0                43605.0  ...               3.9515
# 158                 216644.0                38313.0  ...               3.0062
# 159                 194583.0                48432.0  ...               6.2601
# 160                   9292.0                 3091.0  ...               6.4716
# 161                  10047.0                 2118.0  ...               5.3019
#
#      kcal_vegetables  protein_alcoholic beverages  protein_animal fats  \
# 0             0.7504                       0.0000               0.0277
# 1             2.7508                       0.1840               0.0711
# 2             2.0457                       0.0323               0.0054
# 3             0.3525                       0.6285               0.0277
# 4             1.2960                       0.1535               0.1289
# ..               ...                          ...                  ...
# 157           0.3636                       0.0000               0.0188
# 158           0.4472                       0.4824               0.0338
# 159           0.2532                       0.2929               0.0391
# 160           0.9998                       0.3262               0.1873
# 161           0.8551                       0.3778               0.2042
#
#      protein_milk - excluding butter  protein_oilcrops  protein_stimulants  \
# 0                             5.5278            0.2034              0.5546
# 1                            16.4750            0.3722              0.2635
# 2                             8.0616            0.1830              0.4628
# 3                             1.1460            2.1534              0.1017
# 4                             7.4349            0.7674              0.4113
# ..                               ...               ...                 ...
# 157                           1.9630            0.2254              0.3193
# 158                           1.0324            8.0562              0.0762
# 159                           2.4114            1.5230              0.2636
# 160                           7.2857            1.2143              0.4591
# 161                           4.7680            1.0618              0.3471
#
#      protein_sugar & sweeteners  protein_vegetable oils  gni_category
# 0                        0.0000                  0.0000       low_gni
# 1                        0.0042                  0.0084       mid_gni
# 2                        0.0000                  0.0269       mid_gni
# 3                        0.0092                  0.0092       mid_gni
# 4                        0.0000                  0.0430       mid_gni
# ..                          ...                     ...           ...
# 157                      0.0000                  0.0000      high_gni
# 158                      0.0000                  0.0000       low_gni
# 159                      0.0000                  0.0293       low_gni
# 160                      0.0000                  0.0362      high_gni
# 161                      0.0000                  0.0153      high_gni
#
# [162 rows x 79 columns]

# %%
df_num = df._get_numeric_data()

# %% [markdown]
# ## Predictive Modeling

# %% [markdown]
# ### X-y split (y is the target variable which is the total claim amount)

# %%
X=df_num.drop(['covid_fatality_rate'], axis=1)
y=df_num.covid_fatality_rate

# %%
X
# Out:
#      covid_confirmed_cases  \
# 0                   158084
# 1                   210224
# 2                   218432
# 3                    81593
# 4                     4283
# ..                     ...
# 157                  10126
# 158                 254274
# 159                 213258
# 160                  63515
# 161                 732268
#
#      age dependency ratio (% of working-age population)  \
# 0                                            86.954464
# 1                                            44.806973
# 2                                            52.617579
# 3                                            99.855751
# 4                                            45.650381
# ..                                                 ...
# 157                                          75.595147
# 158                                          95.402326
# 159                                          80.391033
# 160                                          47.920177
# 161                                          42.229689
#
#      age dependency ratio, old  age population, age 0, female, interpolated  \
# 0                     4.616073                                     470554.0
# 1                    17.950766                                      21438.0
# 2                     9.062490                                     459353.0
# 3                     4.623604                                     502641.0
# 4                    10.434645                                        734.0
# ..                         ...                                          ...
# 157                   4.893864                                     392662.0
# 158                   5.683539                                     295178.0
# 159                   5.347744                                     262428.0
# 160                  15.042344                                       1990.0
# 161                  10.738501                                       2952.0
#
#      diabetes prevalence (% of population ages 20 to 79)  \
# 0                                                  8.8
# 1                                                 10.3
# 2                                                  7.5
# 3                                                  4.1
# 4                                                 13.6
# ..                                                 ...
# 157                                                5.1
# 158                                                4.1
# 159                                                3.9
# 160                                               19.6
# 161                                               19.4
#
#      female population 45-49  female population 80+  \
# 0                   496113.0                43481.0
# 1                    97198.0                41381.0
# 2                  1053861.0               253907.0
# 3                   383280.0                38663.0
# 4                     4400.0                  947.0
# ..                       ...                    ...
# 157                 409910.0                43605.0
# 158                 216644.0                38313.0
# 159                 194583.0                48432.0
# 160                   9292.0                 3091.0
# 161                  10047.0                 2118.0
#
#      gni per capita, atlas method (current us$)  \
# 0                                      630.0000
# 1                                     4290.0000
# 2                                     4870.0000
# 3                                     4180.0000
# 4                                    13390.0000
# ..                                          ...
# 157                                  13410.2027
# 158                                   1500.0000
# 159                                    850.0000
# 160                                  13410.2027
# 161                                  13410.2027
#
#      immunization, dpt (% of children ages 12-23 months)  \
# 0                                            78.000000
# 1                                            98.000000
# 2                                            95.000000
# 3                                            64.000000
# 4                                            99.000000
# ..                                                 ...
# 157                                          69.000000
# 158                                          90.000000
# 159                                          87.000000
# 160                                          88.708075
# 161                                          88.708075
#
#      immunization, hib3 (% of children ages 12-23 months)  ...  \
# 0                                            78.000000     ...
# 1                                            98.000000     ...
# 2                                            95.000000     ...
# 3                                            64.000000     ...
# 4                                            99.000000     ...
# ..                                                 ...     ...
# 157                                          69.000000     ...
# 158                                          90.000000     ...
# 159                                          87.000000     ...
# 160                                          87.474684     ...
# 161                                          87.474684     ...
#
#      kcal_sugar & sweeteners  kcal_vegetable oils  kcal_vegetables  \
# 0                     2.2261               2.3012           0.7504
# 1                     3.4422               2.8244           2.7508
# 2                     3.9869               5.7638           2.0457
# 3                     2.7539               4.2741           0.3525
# 4                     5.8218               4.6904           1.2960
# ..                       ...                  ...              ...
# 157                   7.0303               3.9515           0.3636
# 158                   2.5590               3.0062           0.4472
# 159                   5.0403               6.2601           0.2532
# 160                   4.2720               6.4716           0.9998
# 161                   3.5574               5.3019           0.8551
#
#      protein_alcoholic beverages  protein_animal fats  \
# 0                         0.0000               0.0277
# 1                         0.1840               0.0711
# 2                         0.0323               0.0054
# 3                         0.6285               0.0277
# 4                         0.1535               0.1289
# ..                           ...                  ...
# 157                       0.0000               0.0188
# 158                       0.4824               0.0338
# 159                       0.2929               0.0391
# 160                       0.3262               0.1873
# 161                       0.3778               0.2042
#
#      protein_milk - excluding butter  protein_oilcrops  protein_stimulants  \
# 0                             5.5278            0.2034              0.5546
# 1                            16.4750            0.3722              0.2635
# 2                             8.0616            0.1830              0.4628
# 3                             1.1460            2.1534              0.1017
# 4                             7.4349            0.7674              0.4113
# ..                               ...               ...                 ...
# 157                           1.9630            0.2254              0.3193
# 158                           1.0324            8.0562              0.0762
# 159                           2.4114            1.5230              0.2636
# 160                           7.2857            1.2143              0.4591
# 161                           4.7680            1.0618              0.3471
#
#      protein_sugar & sweeteners  protein_vegetable oils
# 0                        0.0000                  0.0000
# 1                        0.0042                  0.0084
# 2                        0.0000                  0.0269
# 3                        0.0092                  0.0092
# 4                        0.0000                  0.0430
# ..                          ...                     ...
# 157                      0.0000                  0.0000
# 158                      0.0000                  0.0000
# 159                      0.0000                  0.0293
# 160                      0.0000                  0.0362
# 161                      0.0000                  0.0153
#
# [162 rows x 75 columns]

# %% [markdown]
# <
