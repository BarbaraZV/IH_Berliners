# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import glob
import qgrid

# %% [markdown]
# ## Loading the Dataset

# %%
def load_csv_dataframes(path):
    '''Loads all csv files in a folder and stores them in a list of dataframes.
    Returns list of dataframes.
    [attributes]
    path: path of folder with csvs inside
    '''
    all_files = glob.glob(path + "/*.csv")
    dataframes_list=[]
    file_count=len(all_files)
    for i in range(file_count):
        temp_df = pd.read_csv(all_files[i])
        dataframes_list.append(temp_df)
        
    return dataframes_list

# %%
####1. Load relevant csv files. 
### INPUT -- folder_path for file

# Update folder_path to grab all csv files in folder
folder_path = r"Data\3. Full merge no nan\full_merge_no_nans.csv"

df= pd.read_csv(folder_path)

# %%
df
# Out:
#                  country  age dependency ratio (% of working-age population)  \
# 0            afghanistan                                          86.954464
# 1                albania                                          44.806973
# 2                algeria                                          52.617579
# 3                 angola                                          99.855751
# 4    antigua and barbuda                                          45.650381
# ..                   ...                                                ...
# 142           uzbekistan                                          49.650534
# 143              vanuatu                                          68.719678
# 144              vietnam                                          42.511440
# 145               zambia                                          95.402326
# 146             zimbabwe                                          80.391033
#
#      age dependency ratio, old  age dependency ratio, young  \
# 0                     4.616073                    82.338391
# 1                    17.950766                    26.856206
# 2                     9.062490                    43.555089
# 3                     4.623604                    95.232147
# 4                    10.434645                    35.215736
# ..                         ...                          ...
# 142                   6.970327                    42.680207
# 143                   7.084707                    61.634972
# 144                   9.605993                    32.905446
# 145                   5.683539                    89.718788
# 146                   5.347744                    75.043289
#
#      age population, age 0, female, interpolated  \
# 0                                         470554
# 1                                          21438
# 2                                         459353
# 3                                         502641
# 4                                            734
# ..                                           ...
# 142                                       318305
# 143                                         3215
# 144                                       733682
# 145                                       295178
# 146                                       262428
#
#      age population, age 0, male, interpolated  \
# 0                                       498844
# 1                                        23178
# 2                                       476141
# 3                                       510719
# 4                                          744
# ..                                         ...
# 142                                     332916
# 143                                       3455
# 144                                     816544
# 145                                     301320
# 146                                     264810
#
#      age population, age 01, female, interpolated  \
# 0                                          479012
# 1                                           19177
# 2                                          460749
# 3                                          485224
# 4                                             727
# ..                                            ...
# 142                                        317447
# 143                                          3330
# 144                                        737160
# 145                                        289170
# 146                                        256385
#
#      age population, age 01, male, interpolated  \
# 0                                        505348
# 1                                         20669
# 2                                        476982
# 3                                        491924
# 4                                           736
# ..                                          ...
# 142                                      331971
# 143                                        3566
# 144                                      821987
# 145                                      294786
# 146                                      258392
#
#      age population, age 02, female, interpolated  \
# 0                                          484823
# 1                                           17406
# 2                                          456245
# 3                                          468369
# 4                                             722
# ..                                            ...
# 142                                        314294
# 143                                          3400
# 144                                        736193
# 145                                        282804
# 146                                        249923
#
#      age population, age 02, male, interpolated  ...  protein_spices  \
# 0                                        509720  ...          0.1664
# 1                                         18721  ...          0.0000
# 2                                        471814  ...          0.1776
# 3                                        473922  ...          0.0000
# 4                                           730  ...          0.3438
# ..                                          ...  ...             ...
# 142                                      328606  ...          0.0160
# 143                                        3634  ...          0.1177
# 144                                      821086  ...          0.5221
# 145                                      287939  ...          0.0846
# 146                                      251613  ...          0.0488
#
#      protein_starchy roots  protein_stimulants  protein_sugar & sweeteners  \
# 0                   0.1941              0.5546                      0.0000
# 1                   0.8867              0.2635                      0.0042
# 2                   1.4638              0.4628                      0.0000
# 3                   5.1941              0.1017                      0.0092
# 4                   0.4666              0.4113                      0.0000
# ..                     ...                 ...                         ...
# 142                 1.2509              0.1604                      0.0000
# 143                 5.7347              0.0863                      0.0000
# 144                 0.2333              0.5444                      0.0056
# 145                 1.2863              0.0762                      0.0000
# 146                 0.5467              0.2636                      0.0000
#
#      protein_treenuts  protein_vegetal products  protein_vegetable oils  \
# 0              0.1387                   40.2477                  0.0000
# 1              0.2677                   22.2552                  0.0084
# 2              0.2745                   36.1694                  0.0269
# 3              0.0092                   34.7782                  0.0092
# 4              0.0737                   16.8161                  0.0430
# ..                ...                       ...                     ...
# 142            0.1657                   29.9781                  0.0053
# 143            0.0157                   30.1247                  0.0078
# 144            0.3277                   29.5617                  0.0000
# 145            0.0000                   40.1117                  0.0000
# 146            0.1367                   38.6508                  0.0293
#
#      protein_vegetables  protein_miscellaneous  mortality_rate_covid
# 0                1.1370                 0.0462              4.352069
# 1                3.2456                 0.0544              1.717095
# 2                3.1267                 0.1399              2.677922
# 3                0.8133                 0.0924              2.367660
# 4                1.6024                 0.2947              2.430556
# ..                  ...                    ...                   ...
# 142              3.9985                 0.0321              0.785628
# 143              1.5847                 0.1020              0.000000
# 144              3.7216                 0.0389              1.763224
# 145              0.8039                 0.0592              1.365849
# 146              0.5955                 0.0586              3.815931
#
# [147 rows x 255 columns]

# %% [markdown]
# ## Structured Based Data Exploration

# %% [markdown]
# <b> Displaying the first 5 rows

# %%
df.head()
# Out:
#                country  age dependency ratio (% of working-age population)  \
# 0          afghanistan                                          86.954464
# 1              albania                                          44.806973
# 2              algeria                                          52.617579
# 3               angola                                          99.855751
# 4  antigua and barbuda                                          45.650381
#
#    age dependency ratio, old  age dependency ratio, young  \
# 0                   4.616073                    82.338391
# 1                  17.950766                    26.856206
# 2                   9.062490                    43.555089
# 3                   4.623604                    95.232147
# 4                  10.434645                    35.215736
#
#    age population, age 0, female, interpolated  \
# 0                                       470554
# 1                                        21438
# 2                                       459353
# 3                                       502641
# 4                                          734
#
#    age population, age 0, male, interpolated  \
# 0                                     498844
# 1                                      23178
# 2                                     476141
# 3                                     510719
# 4                                        744
#
#    age population, age 01, female, interpolated  \
# 0                                        479012
# 1                                         19177
# 2                                        460749
# 3                                        485224
# 4                                           727
#
#    age population, age 01, male, interpolated  \
# 0                                      505348
# 1                                       20669
# 2                                      476982
# 3                                      491924
# 4                                         736
#
#    age population, age 02, female, interpolated  \
# 0                                        484823
# 1                                         17406
# 2                                        456245
# 3                                        468369
# 4                                           722
#
#    age population, age 02, male, interpolated  ...  protein_spices  \
# 0                                      509720  ...          0.1664
# 1                                       18721  ...          0.0000
# 2                                      471814  ...          0.1776
# 3                                      473922  ...          0.0000
# 4                                         730  ...          0.3438
#
#    protein_starchy roots  protein_stimulants  protein_sugar & sweeteners  \
# 0                 0.1941              0.5546                      0.0000
# 1                 0.8867              0.2635                      0.0042
# 2                 1.4638              0.4628                      0.0000
# 3                 5.1941              0.1017                      0.0092
# 4                 0.4666              0.4113                      0.0000
#
#    protein_treenuts  protein_vegetal products  protein_vegetable oils  \
# 0            0.1387                   40.2477                  0.0000
# 1            0.2677                   22.2552                  0.0084
# 2            0.2745                   36.1694                  0.0269
# 3            0.0092                   34.7782                  0.0092
# 4            0.0737                   16.8161                  0.0430
#
#    protein_vegetables  protein_miscellaneous  mortality_rate_covid
# 0              1.1370                 0.0462              4.352069
# 1              3.2456                 0.0544              1.717095
# 2              3.1267                 0.1399              2.677922
# 3              0.8133                 0.0924              2.367660
# 4              1.6024                 0.2947              2.430556
#
# [5 rows x 255 columns]

# %% [markdown]
# <b> Displaying the last 5 rows

# %%
df.tail()
# Out:
#         country  age dependency ratio (% of working-age population)  \
# 142  uzbekistan                                          49.650534
# 143     vanuatu                                          68.719678
# 144     vietnam                                          42.511440
# 145      zambia                                          95.402326
# 146    zimbabwe                                          80.391033
#
#      age dependency ratio, old  age dependency ratio, young  \
# 142                   6.970327                    42.680207
# 143                   7.084707                    61.634972
# 144                   9.605993                    32.905446
# 145                   5.683539                    89.718788
# 146                   5.347744                    75.043289
#
#      age population, age 0, female, interpolated  \
# 142                                       318305
# 143                                         3215
# 144                                       733682
# 145                                       295178
# 146                                       262428
#
#      age population, age 0, male, interpolated  \
# 142                                     332916
# 143                                       3455
# 144                                     816544
# 145                                     301320
# 146                                     264810
#
#      age population, age 01, female, interpolated  \
# 142                                        317447
# 143                                          3330
# 144                                        737160
# 145                                        289170
# 146                                        256385
#
#      age population, age 01, male, interpolated  \
# 142                                      331971
# 143                                        3566
# 144                                      821987
# 145                                      294786
# 146                                      258392
#
#      age population, age 02, female, interpolated  \
# 142                                        314294
# 143                                          3400
# 144                                        736193
# 145                                        282804
# 146                                        249923
#
#      age population, age 02, male, interpolated  ...  protein_spices  \
# 142                                      328606  ...          0.0160
# 143                                        3634  ...          0.1177
# 144                                      821086  ...          0.5221
# 145                                      287939  ...          0.0846
# 146                                      251613  ...          0.0488
#
#      protein_starchy roots  protein_stimulants  protein_sugar & sweeteners  \
# 142                 1.2509              0.1604                      0.0000
# 143                 5.7347              0.0863                      0.0000
# 144                 0.2333              0.5444                      0.0056
# 145                 1.2863              0.0762                      0.0000
# 146                 0.5467              0.2636                      0.0000
#
#      protein_treenuts  protein_vegetal products  protein_vegetable oils  \
# 142            0.1657                   29.9781                  0.0053
# 143            0.0157                   30.1247                  0.0078
# 144            0.3277                   29.5617                  0.0000
# 145            0.0000                   40.1117                  0.0000
# 146            0.1367                   38.6508                  0.0293
#
#      protein_vegetables  protein_miscellaneous  mortality_rate_covid
# 142              3.9985                 0.0321              0.785628
# 143              1.5847                 0.1020              0.000000
# 144              3.7216                 0.0389              1.763224
# 145              0.8039                 0.0592              1.365849
# 146              0.5955                 0.0586              3.815931
#
# [5 rows x 255 columns]

# %% [markdown]
# <b> Displaying the Number of Variables and Observations

# %%
#In this Dataframe, there are 147 rows X 255 columns
df.shape
# Out:
# (147, 255)

# %% [markdown]
# <b> Display the Variable Names and Data Types

# %%
qgrid.show_grid(df.dtypes, grid_options={'forceFitColumns': False})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# <b> Count the number of Non-Missing Values for each variable

# %%
qgrid.show_grid(df.count(), grid_options={'forceFitColumns': False})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# <b> Descriptive Statistics

# %%
#Statistical information of all numerical features in the dataframe
qgrid.show_grid(df.describe(include = 'all'), grid_options={'forceFitColumns': False})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# <b> Displaying the Complete Summary of the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Columns: 255 entries, country to mortality_rate_covid
# dtypes: float64(150), int64(104), object(1)
# memory usage: 293.0+ KB

# %%
qgrid.show_grid(df.isnull().sum(), grid_options={'forceFitColumns': False})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# ## Target Variable

# %%
plt.figure(figsize = (5,5))
sns.countplot(x=df['mortality_rate_covid']), palette = 'Greens', linewidth = 1)
plt.show()
# Out:
#   Input In [43]
#     sns.countplot(x=df['mortality_rate_covid']), palette = 'Greens', linewidth = 1)
#     ^
# SyntaxError: cannot assign to function call
