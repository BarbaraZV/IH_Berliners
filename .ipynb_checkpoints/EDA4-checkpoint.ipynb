# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import glob
import qgrid

# %% [markdown]
# ## Loading the Dataset

# %%
def load_csv_dataframes(path):
    '''Loads all csv files in a folder and stores them in a list of dataframes.
    Returns list of dataframes.
    [attributes]
    path: path of folder with csvs inside
    '''
    all_files = glob.glob(path + "/*.csv")
    dataframes_list=[]
    file_count=len(all_files)
    for i in range(file_count):
        temp_df = pd.read_csv(all_files[i])
        dataframes_list.append(temp_df)
        
    return dataframes_list

# %%
####1. Load relevant csv files. 
### INPUT -- folder_path for file

# Update folder_path to grab all csv files in folder
folder_path = r"Data\\5. Updated with continent codes\nutrition_demographic_covid_continent.csv"

df= pd.read_csv(folder_path)

# %%
df
# Out:
#          continent              country  covid_confirmed_cases  covid_deaths  \
# 0             asia          afghanistan                 158084          7356
# 1           europe              albania                 210224          3217
# 2           africa              algeria                 218432          6276
# 3           africa               angola                  81593          1770
# 4    north america  antigua and barbuda                   4283           119
# ..             ...                  ...                    ...           ...
# 157           asia                yemen                  10126          1984
# 158         africa               zambia                 254274          3734
# 159         africa             zimbabwe                 213258          5004
# 160        oceania        new caledonia                  63515           313
# 161        oceania     french polynesia                 732268           649
#
#      covid_fatality_rate  age dependency ratio (% of working-age population)  \
# 0               0.000226                                          86.954464
# 1               0.001113                                          44.806973
# 2               0.000158                                          52.617579
# 3               0.000071                                          99.855751
# 4               0.001296                                          45.650381
# ..                   ...                                                ...
# 157             0.000074                                          75.595147
# 158             0.000230                                          95.402326
# 159             0.000321                                          80.391033
# 160             0.001147                                          47.920177
# 161             0.002295                                          42.229689
#
#      age dependency ratio, old  age dependency ratio, young  \
# 0                     4.616073                    82.338391
# 1                    17.950766                    26.856206
# 2                     9.062490                    43.555089
# 3                     4.623604                    95.232147
# 4                    10.434645                    35.215736
# ..                         ...                          ...
# 157                   4.893864                    70.701283
# 158                   5.683539                    89.718788
# 159                   5.347744                    75.043289
# 160                  15.042344                    32.877833
# 161                  10.738501                    31.491187
#
#      age population, age 0, female, interpolated  \
# 0                                       470554.0
# 1                                        21438.0
# 2                                       459353.0
# 3                                       502641.0
# 4                                          734.0
# ..                                           ...
# 157                                     392662.0
# 158                                     295178.0
# 159                                     262428.0
# 160                                       1990.0
# 161                                       2952.0
#
#      age population, age 0, male, interpolated  ...  protein_spices  \
# 0                                     498844.0  ...          0.1664
# 1                                      23178.0  ...          0.0000
# 2                                     476141.0  ...          0.1776
# 3                                     510719.0  ...          0.0000
# 4                                        744.0  ...          0.3438
# ..                                         ...  ...             ...
# 157                                   409629.0  ...          0.0657
# 158                                   301320.0  ...          0.0846
# 159                                   264810.0  ...          0.0488
# 160                                     2053.0  ...          0.0967
# 161                                     3000.0  ...          0.0255
#
#      protein_starchy roots  protein_stimulants  protein_sugar & sweeteners  \
# 0                   0.1941              0.5546                      0.0000
# 1                   0.8867              0.2635                      0.0042
# 2                   1.4638              0.4628                      0.0000
# 3                   5.1941              0.1017                      0.0092
# 4                   0.4666              0.4113                      0.0000
# ..                     ...                 ...                         ...
# 157                 0.2066              0.3193                      0.0000
# 158                 1.2863              0.0762                      0.0000
# 159                 0.5467              0.2636                      0.0000
# 160                 0.7431              0.4591                      0.0000
# 161                 0.9036              0.3471                      0.0000
#
#      protein_treenuts  protein_vegetal products  protein_vegetable oils  \
# 0              0.1387                   40.2477                  0.0000
# 1              0.2677                   22.2552                  0.0084
# 2              0.2745                   36.1694                  0.0269
# 3              0.0092                   34.7782                  0.0092
# 4              0.0737                   16.8161                  0.0430
# ..                ...                       ...                     ...
# 157            0.0188                   39.9831                  0.0000
# 158            0.0000                   40.1117                  0.0000
# 159            0.1367                   38.6508                  0.0293
# 160            0.1087                   20.8240                  0.0362
# 161            0.1174                   17.0044                  0.0153
#
#      protein_vegetables  protein_miscellaneous  gni_category
# 0                1.1370                 0.0462       low_gni
# 1                3.2456                 0.0544       mid_gni
# 2                3.1267                 0.1399       mid_gni
# 3                0.8133                 0.0924       mid_gni
# 4                1.6024                 0.2947       mid_gni
# ..                  ...                    ...           ...
# 157              0.5448                 0.0564      high_gni
# 158              0.8039                 0.0592       low_gni
# 159              0.5955                 0.0586       low_gni
# 160              1.7640                 1.1841      high_gni
# 161              1.2558                 1.1129      high_gni
#
# [162 rows x 256 columns]

# %% [markdown]
# ## Structured Based Data Exploration

# %% [markdown]
# <b> Displaying the first 5 rows

# %%
df.head()
# Out:
#        continent              country  covid_confirmed_cases  covid_deaths  \
# 0           asia          afghanistan                 158084          7356
# 1         europe              albania                 210224          3217
# 2         africa              algeria                 218432          6276
# 3         africa               angola                  81593          1770
# 4  north america  antigua and barbuda                   4283           119
#
#    covid_fatality_rate  age dependency ratio (% of working-age population)  \
# 0             0.000226                                          86.954464
# 1             0.001113                                          44.806973
# 2             0.000158                                          52.617579
# 3             0.000071                                          99.855751
# 4             0.001296                                          45.650381
#
#    age dependency ratio, old  age dependency ratio, young  \
# 0                   4.616073                    82.338391
# 1                  17.950766                    26.856206
# 2                   9.062490                    43.555089
# 3                   4.623604                    95.232147
# 4                  10.434645                    35.215736
#
#    age population, age 0, female, interpolated  \
# 0                                     470554.0
# 1                                      21438.0
# 2                                     459353.0
# 3                                     502641.0
# 4                                        734.0
#
#    age population, age 0, male, interpolated  ...  protein_spices  \
# 0                                   498844.0  ...          0.1664
# 1                                    23178.0  ...          0.0000
# 2                                   476141.0  ...          0.1776
# 3                                   510719.0  ...          0.0000
# 4                                      744.0  ...          0.3438
#
#    protein_starchy roots  protein_stimulants  protein_sugar & sweeteners  \
# 0                 0.1941              0.5546                      0.0000
# 1                 0.8867              0.2635                      0.0042
# 2                 1.4638              0.4628                      0.0000
# 3                 5.1941              0.1017                      0.0092
# 4                 0.4666              0.4113                      0.0000
#
#    protein_treenuts  protein_vegetal products  protein_vegetable oils  \
# 0            0.1387                   40.2477                  0.0000
# 1            0.2677                   22.2552                  0.0084
# 2            0.2745                   36.1694                  0.0269
# 3            0.0092                   34.7782                  0.0092
# 4            0.0737                   16.8161                  0.0430
#
#    protein_vegetables  protein_miscellaneous  gni_category
# 0              1.1370                 0.0462       low_gni
# 1              3.2456                 0.0544       mid_gni
# 2              3.1267                 0.1399       mid_gni
# 3              0.8133                 0.0924       mid_gni
# 4              1.6024                 0.2947       mid_gni
#
# [5 rows x 256 columns]

# %% [markdown]
# <b> Displaying the last 5 rows

# %%
df.tail()
# Out:
#     continent           country  covid_confirmed_cases  covid_deaths  \
# 157      asia             yemen                  10126          1984
# 158    africa            zambia                 254274          3734
# 159    africa          zimbabwe                 213258          5004
# 160   oceania     new caledonia                  63515           313
# 161   oceania  french polynesia                 732268           649
#
#      covid_fatality_rate  age dependency ratio (% of working-age population)  \
# 157             0.000074                                          75.595147
# 158             0.000230                                          95.402326
# 159             0.000321                                          80.391033
# 160             0.001147                                          47.920177
# 161             0.002295                                          42.229689
#
#      age dependency ratio, old  age dependency ratio, young  \
# 157                   4.893864                    70.701283
# 158                   5.683539                    89.718788
# 159                   5.347744                    75.043289
# 160                  15.042344                    32.877833
# 161                  10.738501                    31.491187
#
#      age population, age 0, female, interpolated  \
# 157                                     392662.0
# 158                                     295178.0
# 159                                     262428.0
# 160                                       1990.0
# 161                                       2952.0
#
#      age population, age 0, male, interpolated  ...  protein_spices  \
# 157                                   409629.0  ...          0.0657
# 158                                   301320.0  ...          0.0846
# 159                                   264810.0  ...          0.0488
# 160                                     2053.0  ...          0.0967
# 161                                     3000.0  ...          0.0255
#
#      protein_starchy roots  protein_stimulants  protein_sugar & sweeteners  \
# 157                 0.2066              0.3193                         0.0
# 158                 1.2863              0.0762                         0.0
# 159                 0.5467              0.2636                         0.0
# 160                 0.7431              0.4591                         0.0
# 161                 0.9036              0.3471                         0.0
#
#      protein_treenuts  protein_vegetal products  protein_vegetable oils  \
# 157            0.0188                   39.9831                  0.0000
# 158            0.0000                   40.1117                  0.0000
# 159            0.1367                   38.6508                  0.0293
# 160            0.1087                   20.8240                  0.0362
# 161            0.1174                   17.0044                  0.0153
#
#      protein_vegetables  protein_miscellaneous  gni_category
# 157              0.5448                 0.0564      high_gni
# 158              0.8039                 0.0592       low_gni
# 159              0.5955                 0.0586       low_gni
# 160              1.7640                 1.1841      high_gni
# 161              1.2558                 1.1129      high_gni
#
# [5 rows x 256 columns]

# %% [markdown]
# <b> Displaying the Number of Variables and Observations

# %%
#In this Dataframe, there are 162 rows X 256 columns
df.shape
# Out:
# (162, 256)

# %% [markdown]
# <b> Display the Variable Names and Data Types

# %%
qgrid.show_grid(df.dtypes, grid_options={'forceFitColumns': False})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# <b> Count the number of Non-Missing Values for each variable

# %%
qgrid.show_grid(df.count(), grid_options={'forceFitColumns': False})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# <b> Descriptive Statistics

# %%
#Statistical information of all numerical features in the dataframe
qgrid.show_grid(df.describe(), grid_options={'forceFitColumns': False})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# <b> Displaying the Complete Summary of the Dataset

# %%
qgrid.show_grid(df.info(verbose = True), grid_options={'forceFitColumns': False})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 256 columns):
#  #    Column                                                                     Dtype
# ---   ------                                                                     -----
#  0    continent                                                                  object
#  1    country                                                                    object
#  2    covid_confirmed_cases                                                      int64
#  3    covid_deaths                                                               int64
#  4    covid_fatality_rate                                                        float64
#  5    age dependency ratio (% of working-age population)                         float64
#  6    age dependency ratio, old                                                  float64
#  7    age dependency ratio, young                                                float64
#  8    age population, age 0, female, interpolated                                float64
#  9    age population, age 0, male, interpolated                                  float64
#  10   age population, age 01, female, interpolated                               float64
#  11   age population, age 01, male, interpolated                                 float64
#  12   age population, age 02, female, interpolated                               float64
#  13   age population, age 02, male, interpolated                                 float64
#  14   age population, age 03, female, interpolated                               float64
#  15   age population, age 03, male, interpolated                                 float64
#  16   age population, age 04, female, interpolated                               float64
#  17   age population, age 04, male, interpolated                                 float64
#  18   age population, age 05, female, interpolated                               float64
#  19   age population, age 05, male, interpolated                                 float64
#  20   age population, age 06, female, interpolated                               float64
#  21   age population, age 06, male, interpolated                                 float64
#  22   age population, age 07, female, interpolated                               float64
#  23   age population, age 07, male, interpolated                                 float64
#  24   age population, age 08, female, interpolated                               float64
#  25   age population, age 08, male, interpolated                                 float64
#  26   age population, age 09, female, interpolated                               float64
#  27   age population, age 09, male, interpolated                                 float64
#  28   age population, age 10, female, interpolated                               float64
#  29   age population, age 10, male, interpolated                                 float64
#  30   age population, age 11, female, interpolated                               float64
#  31   age population, age 11, male, interpolated                                 float64
#  32   age population, age 12, female, interpolated                               int64
#  33   age population, age 12, male, interpolated                                 float64
#  34   age population, age 13, female, interpolated                               float64
#  35   age population, age 13, male, interpolated                                 float64
#  36   age population, age 14, female, interpolated                               float64
#  37   age population, age 14, male, interpolated                                 float64
#  38   age population, age 15, female, interpolated                               float64
#  39   age population, age 15, male, interpolated                                 float64
#  40   age population, age 16, female, interpolated                               float64
#  41   age population, age 16, male, interpolated                                 float64
#  42   age population, age 17, female, interpolated                               float64
#  43   age population, age 17, male, interpolated                                 float64
#  44   age population, age 18, female, interpolated                               float64
#  45   age population, age 18, male, interpolated                                 float64
#  46   age population, age 19, female, interpolated                               float64
#  47   age population, age 19, male, interpolated                                 float64
#  48   age population, age 20, female, interpolated                               float64
#  49   age population, age 20, male, interpolated                                 float64
#  50   age population, age 21, female, interpolated                               float64
#  51   age population, age 21, male, interpolated                                 float64
#  52   age population, age 22, female, interpolated                               float64
#  53   age population, age 22, male, interpolated                                 float64
#  54   age population, age 23, female, interpolated                               float64
#  55   age population, age 23, male, interpolated                                 float64
#  56   age population, age 24, female, interpolated                               float64
#  57   age population, age 24, male, interpolated                                 float64
#  58   age population, age 25, female, interpolated                               float64
#  59   age population, age 25, male, interpolated                                 float64
#  60   diabetes prevalence (% of population ages 20 to 79)                        float64
#  61   female population 00-04                                                    float64
#  62   female population 05-09                                                    float64
#  63   female population 10-14                                                    float64
#  64   female population 15-19                                                    int64
#  65   female population 20-24                                                    float64
#  66   female population 25-29                                                    float64
#  67   female population 30-34                                                    float64
#  68   female population 35-39                                                    float64
#  69   female population 40-44                                                    float64
#  70   female population 45-49                                                    float64
#  71   female population 50-54                                                    float64
#  72   female population 55-59                                                    float64
#  73   female population 60-64                                                    float64
#  74   female population 65-69                                                    float64
#  75   female population 70-74                                                    float64
#  76   female population 75-79                                                    float64
#  77   female population 80+                                                      float64
#  78   gni per capita, atlas method (current us$)                                 float64
#  79   immunization, dpt (% of children ages 12-23 months)                        float64
#  80   immunization, hepb3 (% of one-year-old children)                           float64
#  81   immunization, hib3 (% of children ages 12-23 months)                       float64
#  82   immunization, measles (% of children ages 12-23 months)                    float64
#  83   immunization, pol3 (% of one-year-old children)                            float64
#  84   improved sanitation facilities (% of population with access)               float64
#  85   improved sanitation facilities, rural (% of rural population with access)  float64
#  86   improved sanitation facilities, urban (% of urban population with access)  float64
#  87   improved water source (% of population with access)                        float64
#  88   improved water source, rural (% of rural population with access)           float64
#  89   improved water source, urban (% of urban population with access)           float64
#  90   lifetime risk of maternal death (%)                                        float64
#  91   lifetime risk of maternal death (1 in: rate varies by country)             float64
#  92   male population 00-04                                                      float64
#  93   male population 05-09                                                      float64
#  94   male population 10-14                                                      float64
#  95   male population 15-19                                                      float64
#  96   male population 20-24                                                      float64
#  97   male population 25-29                                                      float64
#  98   male population 30-34                                                      float64
#  99   male population 35-39                                                      float64
#  100  male population 40-44                                                      float64
#  101  male population 45-49                                                      float64
#  102  male population 50-54                                                      float64
#  103  male population 55-59                                                      float64
#  104  male population 60-64                                                      float64
#  105  male population 65-69                                                      float64
#  106  male population 70-74                                                      float64
#  107  male population 75-79                                                      float64
#  108  male population 80+                                                        float64
#  109  maternal leave benefits (% of wages paid in covered period)                float64
#  110  maternal mortality ratio (modeled estimate, per 100,000 live births)       float64
#  111  mortality rate, infant (per 1,000 live births)                             float64
#  112  mortality rate, infant, female (per 1,000 live births)                     float64
#  113  mortality rate, infant, male (per 1,000 live births)                       float64
#  114  mortality rate, neonatal (per 1,000 live births)                           float64
#  115  mortality rate, under-5 (per 1,000)                                        float64
#  116  mortality rate, under-5, female (per 1,000)                                float64
#  117  mortality rate, under-5, male (per 1,000)                                  float64
#  118  number of infant deaths                                                    float64
#  119  number of maternal deaths                                                  float64
#  120  number of neonatal deaths                                                  float64
#  121  number of under-five deaths                                                float64
#  122  number of weeks of maternity leave                                         float64
#  123  people practicing open defecation (% of population)                        float64
#  124  people practicing open defecation, rural (% of rural population)           float64
#  125  people practicing open defecation, urban (% of urban population)           float64
#  126  population ages 00-04, female (% of female population)                     float64
#  127  population ages 00-04, male (% of male population)                         float64
#  128  population ages 00-14 (% of total)                                         float64
#  129  population ages 00-14, female (% of total)                                 float64
#  130  population ages 00-14, male (% of total)                                   float64
#  131  population ages 00-14, total                                               float64
#  132  population ages 0-14, female                                               float64
#  133  population ages 0-14, male                                                 float64
#  134  population ages 05-09, female (% of female population)                     float64
#  135  population ages 05-09, male (% of male population)                         float64
#  136  population ages 10-14, female (% of female population)                     float64
#  137  population ages 15-19, female (% of female population)                     float64
#  138  population ages 15-19, male (% of male population)                         float64
#  139  population ages 15-64 (% of total)                                         float64
#  140  population ages 15-64, female                                              float64
#  141  population ages 15-64, female (% of total)                                 float64
#  142  population ages 15-64, male                                                float64
#  143  population ages 15-64, male (% of total)                                   float64
#  144  population ages 15-64, total                                               float64
#  145  population ages 20-24, female (% of female population)                     float64
#  146  population ages 20-24, male (% of male population)                         float64
#  147  population ages 25-29, female (% of female population)                     float64
#  148  population ages 25-29, male (% of male population)                         float64
#  149  population ages 30-34, female (% of female population)                     float64
#  150  population ages 30-34, male (% of male population)                         float64
#  151  population ages 35-39, female (% of female population)                     float64
#  152  population ages 35-39, male (% of male population)                         float64
#  153  population ages 40-44, female (% of female population)                     float64
#  154  population ages 40-44, male (% of male population)                         float64
#  155  population ages 45-49, female (% of female population)                     float64
#  156  population ages 45-49, male (% of male population)                         float64
#  157  population ages 50-54, female (% of female population)                     float64
#  158  population ages 50-54, male (% of male population)                         float64
#  159  population ages 55-59, female (% of female population)                     float64
#  160  population ages 55-59, male (% of male population)                         float64
#  161  population ages 60-64, female (% of female population)                     float64
#  162  population ages 60-64, male (% of male population)                         float64
#  163  population ages 65 and above (% of total)                                  float64
#  164  population ages 65 and above, female                                       float64
#  165  population ages 65 and above, female (% of total)                          float64
#  166  population ages 65 and above, male                                         float64
#  167  population ages 65 and above, male (% of total)                            float64
#  168  population ages 65 and above, total                                        float64
#  169  population ages 65-69, female (% of female population)                     float64
#  170  population ages 65-69, male (% of male population)                         float64
#  171  population ages 70-74, female (% of female population)                     float64
#  172  population ages 70-74, male (% of male population)                         float64
#  173  population ages 75-79, female (% of female population)                     float64
#  174  population ages 75-79, male (% of male population)                         float64
#  175  population ages 80 and older, female (% of female population)              float64
#  176  population ages 80 and older, male (% of male population)                  float64
#  177  population ages10-14, male (% of male population)                          float64
#  178  population growth (annual %)                                               float64
#  179  population, female                                                         float64
#  180  population, female (% of total)                                            float64
#  181  population, male                                                           float64
#  182  population, male (% of total)                                              float64
#  183  population, total                                                          int64
#  184  rural population                                                           float64
#  185  rural population (% of total population)                                   float64
#  186  rural population growth (annual %)                                         float64
#  187  urban population                                                           int64
#  188  urban population (% of total)                                              float64
#  189  urban population growth (annual %)                                         float64
#  190  grand total                                                                float64
#  191  fat_animal products                                                        float64
#  192  fat_animal fats                                                            float64
#  193  fat_cereals - excluding beer                                               float64
#  194  fat_eggs                                                                   float64
#  195  fat_fish, seafood                                                          float64
#  196  fat_fruits - excluding wine                                                float64
#  197  fat_meat                                                                   float64
#  198  fat_miscellaneous                                                          float64
#  199  fat_milk - excluding butter                                                float64
#  200  fat_offals                                                                 float64
#  201  fat_oilcrops                                                               float64
#  202  fat_pulses                                                                 float64
#  203  fat_spices                                                                 float64
#  204  fat_starchy roots                                                          float64
#  205  fat_stimulants                                                             float64
#  206  fat_treenuts                                                               float64
#  207  fat_vegetal products                                                       float64
#  208  fat_vegetable oils                                                         float64
#  209  fat_vegetables                                                             float64
#  210  obesity                                                                    float64
#  211  undernourished                                                             float64
#  212  population                                                                 int64
#  213  kcal_alcoholic beverages                                                   float64
#  214  kcal_animal products                                                       float64
#  215  kcal_animal fats                                                           float64
#  216  kcal_cereals - excluding beer                                              float64
#  217  kcal_eggs                                                                  float64
#  218  kcal_fish, seafood                                                         float64
#  219  kcal_fruits - excluding wine                                               float64
#  220  kcal_meat                                                                  float64
#  221  kcal_milk - excluding butter                                               float64
#  222  kcal_miscellaneous                                                         float64
#  223  kcal_offals                                                                float64
#  224  kcal_oilcrops                                                              float64
#  225  kcal_pulses                                                                float64
#  226  kcal_spices                                                                float64
#  227  kcal_starchy roots                                                         float64
#  228  kcal_stimulants                                                            float64
#  229  kcal_sugar & sweeteners                                                    float64
#  230  kcal_treenuts                                                              float64
#  231  kcal_vegetal products                                                      float64
#  232  kcal_vegetable oils                                                        float64
#  233  kcal_vegetables                                                            float64
#  234  protein_alcoholic beverages                                                float64
#  235  protein_animal products                                                    float64
#  236  protein_animal fats                                                        float64
#  237  protein_cereals - excluding beer                                           float64
#  238  protein_eggs                                                               float64
#  239  protein_fish, seafood                                                      float64
#  240  protein_fruits - excluding wine                                            float64
#  241  protein_meat                                                               float64
#  242  protein_milk - excluding butter                                            float64
#  243  protein_offals                                                             float64
#  244  protein_oilcrops                                                           float64
#  245  protein_pulses                                                             float64
#  246  protein_spices                                                             float64
#  247  protein_starchy roots                                                      float64
#  248  protein_stimulants                                                         float64
#  249  protein_sugar & sweeteners                                                 float64
#  250  protein_treenuts                                                           float64
#  251  protein_vegetal products                                                   float64
#  252  protein_vegetable oils                                                     float64
#  253  protein_vegetables                                                         float64
#  254  protein_miscellaneous                                                      float64
#  255  gni_category                                                               object
# dtypes: float64(246), int64(7), object(3)
# memory usage: 324.1+ KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 qgrid.show_grid(df.info(verbose = True), grid_options={'forceFitColumns': False})
#
# File ~\anaconda3\envs\BV_Env\lib\site-packages\qgrid\grid.py:499, in show_grid(data_frame, show_toolbar, precision, grid_options, column_options, column_definitions, row_edit_callback)
#     497     data_frame = pd.DataFrame(data_frame)
#     498 elif not isinstance(data_frame, pd.DataFrame):
# --> 499     raise TypeError(
#     500         "data_frame must be DataFrame or Series, not %s" % type(data_frame)
#     501     )
#     503 column_definitions = (column_definitions or {})
#     505 # create a visualization for the dataframe
#
# TypeError: data_frame must be DataFrame or Series, not <class 'NoneType'>

# %% [markdown]
# <b> Null vaues

# %%
qgrid.show_grid(df.isnull().sum(), grid_options={'forceFitColumns': False})

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# ## Target Variable

# %%
plt.scatter(df.index,df['covid_fatality_rate'])
plt.title("Univariate scatter plot")
plt.xlabel("Observation number")
plt.ylabel("Covid fatality rate")
plt.show()

# %% [markdown]
# ## Correlation matrix

# %% [markdown]
# ### Deleting correlated variables (90% treshold)

# %%
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr().abs()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
                if colname in dataset.columns:
                    del dataset[colname] # deleting the column from the dataset

    return dataset

# %%
corr90 = correlation(df, 0.9)

# %% [markdown]
# <b> Dataframe with dropped columns

# %%
corr90

# %%
#corr90.columns

# %% [markdown]
# ### Correlation matrix

# %%
corr_matrix=df.corr()

qgrid.show_grid(corr_matrix.abs(), grid_options={'forceFitColumns': False})

# %%
plt.figure(figsize=(9, 8))
sns.distplot(df['covid_fatality_rate'], color='g', bins=100, hist_kws={'alpha': 0.4});

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()

# %%
df_num.hist(figsize=(40, 35), bins=50, xlabelsize=15, ylabelsize=10);

# %%
df_num=df.select_dtypes(include=['float64','int64'])
df_num
col_name=df_num.columns
for i in col_name:
    plt.figure(figsize=(8,5))
    sns.scatterplot(x='covid_deaths',y=i, data=df,x_bins=1000)

# %%
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(40, 30))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
# Create the plot
fig, ax = plt.subplots()

# Plot the histogram with hist() function
ax.hist(df, edgecolor = "black", bins = 5)

# Label axes and set title
ax.set_title("Title")
ax.set_xlabel("X_Label")
ax.set_ylabel("Y_Label")
